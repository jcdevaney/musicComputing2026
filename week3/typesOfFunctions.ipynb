# %% [markdown]
# <a href="https://colab.research.google.com/github/jcdevaney/musicComputing2026/blob/main/week3/typesOfFunctions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Types of Functions

# %%
# create a string
# !git clone https://github.com/jcdevaney/musicComputing2026.git
filename = 'musicComputing2026/audioFiles/avm.wav'
# Out:
# Cloning into 'musicComputing2026'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 54 (delta 22), reused 7 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (54/54), 3.40 MiB | 15.09 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %% [markdown]
# ## Example of a Built-in Function

# %%
# print string
print(filename)
# Out:
# musicComputing2026/audioFiles/avm.wav

# %% [markdown]
# ## Example of an Imported Function

# %%
# import a library and use a function from it
import librosa
sig , sr = librosa.load(filename)

# %% [markdown]
# ## Examples of Built-in Methods

# %%
# use a built in method of the string object
filename.capitalize()
# Out:
# 'Musiccomputing2026/audiofiles/avm.wav'

# %%
filename.isnumeric()
# Out:
# False

# %%
filename.upper()
# Out:
# 'MUSICCOMPUTING2026/AUDIOFILES/AVM.WAV'
