# %% [markdown]
# <a href="https://colab.research.google.com/github/jcdevaney/musicComputing2026/blob/main/week2/week2lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import numpy as np
import matplotlib.pylab as plt
import librosa
import librosa.display

#import audio files
# !git clone https://github.com/jcdevaney/imc2023.git
# Out:
# Cloning into 'imc2023'...
# remote: Enumerating objects: 130, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 130 (delta 28), reused 18 (delta 18), pack-reused 96 (from 1)
# Receiving objects: 100% (130/130), 16.27 MiB | 18.87 MiB/s, done.
# Resolving deltas: 100% (47/47), done.

# %%
# open the audio file avm2.wav with librosa.load()
file = 'imc2023/audioFiles/avm2.wav'
samplingRate = 44100
sig, sr = librosa.load(file,mono=True,sr=samplingRate)

# %%
# plot time domain representation of the signal
plt.plot(sig)

# %%
#adjust the x-axis to represent time
time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sig)

# %%
# scale the y-axis to represent amplitude
excursion=max(abs(sig))
sigNew = sig / excursion
plt.plot(time,sigNew)

# %%
# add x and y labels
plt.plot(time,sigNew)
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
def readAudioFunction(audioFile, samplingRate):
    # remember that you only need to use plt.plot() once

    # open the audio file avm2.wav with librosa.load()

    # adjust the x-axis to represent time

    # scale the y-axis to represent amplitude

    # label the x and y axes
