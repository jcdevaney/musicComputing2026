# %% [markdown]
# <a href="https://colab.research.google.com/github/jcdevaney/musicComputing2026/blob/main/week2/functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def printText(string):
    print(string)

# %%
printText('Hello world!')
# Out:
# Hello world!

# %%
def printTextNum(string,number):
    print(string)
    print(number)

# %%
printTextNum('Hello world!',2)
# Out:
# Hello world!
# 2

# %%
printTextNum('avm.wav',44100)
# Out:
# avm.wav
# 44100
